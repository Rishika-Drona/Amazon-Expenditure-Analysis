# %%
import pandas as pd
# readinf the file into the dataframe
df = pd.read_csv("C:/Users/rishi/Desktop/amazon-orders.csv")
df.head()
# Out:
#   Order Date             Order ID  \
# 0   01/14/20  111-5735977-1213049
# 1   01/27/20  111-8674568-4557007
# 2   01/27/20  111-5012318-6693850
# 3   02/04/20  111-6611322-5533051
# 4   02/04/20  111-2904376-1996261
#
#                                                Title             Category  \
# 0  Braun Epilator Silk-epil 3 3-270, Hair Removal...      ELECTRIC_SHAVER
# 1  Dabur Vatika Enriched Coconut Hair Oil with He...   HAIR_STYLING_AGENT
# 2  UNO Family Card Game, with 112 Cards in a Stur...        TABLETOP_GAME
# 3  Pond's Pure White Deep Cleansing Brightening F...  SKIN_CLEANING_AGENT
# 4                                                NaN                  NaN
#
#     ASIN/ISBN  UNSPSC Code     Website Release Date Condition  \
# 0  B06WGLSRPZ   53131600.0  Amazon.com          NaN       new
# 1  B006BA3BAY   53131602.0  Amazon.com          NaN       new
# 2  B07P6MZPK3   60141103.0  Amazon.com          NaN       new
# ...

# %%
#  to find the full size of the data set with rows and columns
df.shape
# Out:
# (58, 36)

# %%
# Replacing the "NaN" with 0
df = df.fillna(0)
df.head()
# Out:
#   Order Date             Order ID  \
# 0   01/14/20  111-5735977-1213049
# 1   01/27/20  111-8674568-4557007
# 2   01/27/20  111-5012318-6693850
# 3   02/04/20  111-6611322-5533051
# 4   02/04/20  111-2904376-1996261
#
#                                                Title             Category  \
# 0  Braun Epilator Silk-epil 3 3-270, Hair Removal...      ELECTRIC_SHAVER
# 1  Dabur Vatika Enriched Coconut Hair Oil with He...   HAIR_STYLING_AGENT
# 2  UNO Family Card Game, with 112 Cards in a Stur...        TABLETOP_GAME
# 3  Pond's Pure White Deep Cleansing Brightening F...  SKIN_CLEANING_AGENT
# 4                                                  0                    0
#
#     ASIN/ISBN  UNSPSC Code     Website Release Date Condition  \
# 0  B06WGLSRPZ   53131600.0  Amazon.com            0       new
# 1  B006BA3BAY   53131602.0  Amazon.com            0       new
# 2  B07P6MZPK3   60141103.0  Amazon.com            0       new
# ...

# %%
#CLeaning the data by replacing the '$' with nothing and converitng it to float for easier calculation
df["Item Total"] = df['Item Total'].str.replace('$','').astype(float)
df.head()
# Out:
#   Order Date             Order ID  \
# 0   01/14/20  111-5735977-1213049
# 1   01/27/20  111-8674568-4557007
# 2   01/27/20  111-5012318-6693850
# 3   02/04/20  111-6611322-5533051
# 4   02/04/20  111-2904376-1996261
#
#                                                Title             Category  \
# 0  Braun Epilator Silk-epil 3 3-270, Hair Removal...      ELECTRIC_SHAVER
# 1  Dabur Vatika Enriched Coconut Hair Oil with He...   HAIR_STYLING_AGENT
# 2  UNO Family Card Game, with 112 Cards in a Stur...        TABLETOP_GAME
# 3  Pond's Pure White Deep Cleansing Brightening F...  SKIN_CLEANING_AGENT
# 4                                                  0                    0
#
#     ASIN/ISBN  UNSPSC Code     Website Release Date Condition  \
# 0  B06WGLSRPZ   53131600.0  Amazon.com            0       new
# 1  B006BA3BAY   53131602.0  Amazon.com            0       new
# 2  B07P6MZPK3   60141103.0  Amazon.com            0       new
# ...

# %%
# total expenditure
df["Item Total"].sum()
# Out:
# 1421.6

# %%
# average purchased price
df["Item Total"].mean()
# Out:
# 24.510344827586206

# %%
#to find the outliers
df["Item Total"].median()
# Out:
# 20.07

# %%
#Maximum Spent
df["Item Total"].max()
# Out:
# 121.26

# %%
# Minimum Spent
df["Item Total"].min()
# Out:
# 0.0

# %%
#CLeaning the data by replacing the '$' with nothing and converitng it to float for easier calculation
df["Item Subtotal Tax"] = df['Item Subtotal Tax'].str.replace('$','').astype(float)
df.head()
# Out:
#   Order Date             Order ID  \
# 0   01/14/20  111-5735977-1213049
# 1   01/27/20  111-8674568-4557007
# 2   01/27/20  111-5012318-6693850
# 3   02/04/20  111-6611322-5533051
# 4   02/04/20  111-2904376-1996261
#
#                                                Title             Category  \
# 0  Braun Epilator Silk-epil 3 3-270, Hair Removal...      ELECTRIC_SHAVER
# 1  Dabur Vatika Enriched Coconut Hair Oil with He...   HAIR_STYLING_AGENT
# 2  UNO Family Card Game, with 112 Cards in a Stur...        TABLETOP_GAME
# 3  Pond's Pure White Deep Cleansing Brightening F...  SKIN_CLEANING_AGENT
# 4                                                  0                    0
#
#     ASIN/ISBN  UNSPSC Code     Website Release Date Condition  \
# 0  B06WGLSRPZ   53131600.0  Amazon.com            0       new
# 1  B006BA3BAY   53131602.0  Amazon.com            0       new
# 2  B07P6MZPK3   60141103.0  Amazon.com            0       new
# ...

# %%
df["Item Subtotal Tax"].sum()
# Out:
# 90.6

# %%
# To analyse the overall tax paid from the bought items
df["Item Subtotal Tax"].sum()/df["Item Total"].sum()
# Out:
# 0.06373100731570062

# %%
# Converting the the date into datetime data type so that it becomes easy for the systemt o recognize them as dates
df["Order Date"] = pd.to_datetime(df["Order Date"])
df.head()
# Out:
#   Order Date             Order ID  \
# 0 2020-01-14  111-5735977-1213049
# 1 2020-01-27  111-8674568-4557007
# 2 2020-01-27  111-5012318-6693850
# 3 2020-02-04  111-6611322-5533051
# 4 2020-02-04  111-2904376-1996261
#
#                                                Title             Category  \
# 0  Braun Epilator Silk-epil 3 3-270, Hair Removal...      ELECTRIC_SHAVER
# 1  Dabur Vatika Enriched Coconut Hair Oil with He...   HAIR_STYLING_AGENT
# 2  UNO Family Card Game, with 112 Cards in a Stur...        TABLETOP_GAME
# 3  Pond's Pure White Deep Cleansing Brightening F...  SKIN_CLEANING_AGENT
# 4                                                  0                    0
#
#     ASIN/ISBN  UNSPSC Code     Website Release Date Condition  \
# 0  B06WGLSRPZ   53131600.0  Amazon.com            0       new
# 1  B006BA3BAY   53131602.0  Amazon.com            0       new
# 2  B07P6MZPK3   60141103.0  Amazon.com            0       new
# ...

# %%
# Analysis of expenditure on each particular day in dataset by using matplotlib package which will allow us to display charts in the notebook.
# %matplotlib inline

# %%
# Passing the desired X and Y axis columns to the above function as an argument and adding other argument like to rotate the x- axis labels
df.plot.bar(x="Order Date", y="Item Total", rot = 90)

# %%
# To create a bigger size of the above figure to make it more visible by passing an argument. It allows to define the size of the graph by width and size
df.plot.bar(x="Order Date", y="Item Total", rot = 90, figsize=(20,10))

# %%
# To get the same bar for the orders placed on the same date since we need to observe the total spent on particular day
daily_orders = df.groupby("Order Date").sum()["Item Total"]
daily_orders.head()
# Out:
# Order Date
# 2020-01-14    37.39
# 2020-01-27    19.63
# 2020-02-04    22.32
# 2020-05-14    23.74
# 2020-06-11    13.85
# Name: Item Total, dtype: float64

# %%
#The results of "head()" above looks a bit different here. That’s because this is a Series rather than a DataFrame. It looks like it has two columns, but it actually only has one: the 'Order Date' column entries are actually the index labels for our sums.These numbers are index labels. So converting them into bar graph would be as follows:
daily_orders.plot.bar(figsize=(20,10))

# %%
# to change the color of the bars for example green
daily_orders.plot.bar(figsize=(20,10), color="#61D199")
